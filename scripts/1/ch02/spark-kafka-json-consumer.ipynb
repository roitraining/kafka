# %% [markdown]
# ## Run the following to start a spark job:

# %%
! spark-submit --packages org.apache.spark:spark-sql-kafka-0-10_2.12:3.2.1 spark-kafka-json-kafka.py
# Out:
# :: loading settings :: url = jar:file:/usr/local/spark-3.2.1-bin-hadoop3.2/jars/ivy-2.5.0.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /root/.ivy2/cache
# The jars for the packages stored in: /root/.ivy2/jars
# org.apache.spark#spark-sql-kafka-0-10_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-ea364a57-6257-4398-85b6-6b11a10e2270;1.0
# 	confs: [default]
# 	found org.apache.spark#spark-sql-kafka-0-10_2.12;3.2.1 in central
# 	found org.apache.spark#spark-token-provider-kafka-0-10_2.12;3.2.1 in central
# 	found org.apache.kafka#kafka-clients;2.8.0 in central
# 	found org.lz4#lz4-java;1.7.1 in central
# 	found org.xerial.snappy#snappy-java;1.1.8.4 in central
# 	found org.slf4j#slf4j-api;1.7.30 in central
# 	found org.apache.hadoop#hadoop-client-runtime;3.3.1 in central
# 	found org.spark-project.spark#unused;1.0.0 in spark-list
# 	found org.apache.hadoop#hadoop-client-api;3.3.1 in central
# ...

# %% [markdown]
# ## This example will read the stream `stocks-json`, and just do a minor uppercase transform on the data and republish them as new messages to the kafka stream `classroom`.

# %%
from kafka import KafkaConsumer
consumer = KafkaConsumer('classroom')
for event in consumer:
   print(event)
# Out:
# ConsumerRecord(topic='classroom', partition=0, offset=31927, timestamp=1645111563463, timestamp_type=0, key=None, value=b'{"EVENT_TIME": "2022-02-17 15:24:14", "SYMBOL": "AAPL", "PRICE": 101.76, "QUANTITY": 733}', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=89, serialized_header_size=-1)
# ConsumerRecord(topic='classroom', partition=0, offset=31928, timestamp=1645111563473, timestamp_type=0, key=None, value=b'{"EVENT_TIME": "2022-02-17 15:24:14", "SYMBOL": "MSFT", "PRICE": 281.38, "QUANTITY": 532}', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=89, serialized_header_size=-1)
# ConsumerRecord(topic='classroom', partition=0, offset=31929, timestamp=1645111563474, timestamp_type=0, key=None, value=b'{"EVENT_TIME": "2022-02-17 15:24:14", "SYMBOL": "GOOG", "PRICE": 169.45, "QUANTITY": 273}', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=89, serialized_header_size=-1)
# ...
